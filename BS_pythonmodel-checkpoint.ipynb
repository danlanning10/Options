# %%
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt
import math as m
import random as r

def terminal_shareprice(S_0, risk_free_rate, sigma, Z, T):
    """
    Generates the terminal share price given some random normal values, z
    """
    # It returns an array of terminal stock prices.
    return S_0*np.exp((risk_free_rate-sigma**2/2)*T+sigma*np.sqrt(T)*Z)
  
def discounted_put_payoff(S_T, K, risk_free_rate, T):
    """
    Function for evaluating the discounted payoff of a put option
    in the Monte Carlo Estimation
    """
    # It returns an array which has the value of the put for each terminal stock price.
    return np.exp(-risk_free_rate*T)*np.maximum(K - S_T, 0)

# %%
# Standard options
# Share specific info
risk_free = 0.1
S_0 = 100
sigma = 0.3

# Option specific info
strike = 110
T = 1
current_time = 0

# Generate Monte Carlo estimates of Vanilla European Put Options
np.random.seed(0)

sample_sizes = 5000
N = 10

# initialize the result as an array and the standard deviations as an array of size sample sizes
mput_est = [None]*sample_sizes
mput_std = [None]*sample_sizes

# Generating Monte Carlo estimates as a function of sample size
# The for loop implements Monte Carlo for a number of different sample sizes.
for i in range(1, sample_sizes+1):
    
    # we need N new random variables for each N increasing by a factor of i
    norm_array = norm.rvs(size = N*i)
    
    # used to simulate terminal stock prices
    term_val = terminal_shareprice(S_0, risk_free, sigma, norm_array, T-current_time)
    
    # These terminal stock prices are passed into the function which values 
    # a put on the stock
    mput_val = discounted_put_payoff(term_val, strike, risk_free, T-current_time)
    
    # store the mean and SD of these put values
    mput_est[i-1] = np.mean(mput_val)
    mput_std[i-1] = np.std(mput_val)/np.sqrt(i*N)

# %%
# Double risk free
# Share specific info
risk_free_M = 0.4
S_0 = 100
sigma = 0.3

# Option specific info
strike = 110
T = 1
current_time = 0

# Generate Monte Carlo estimates of Vanilla European Put Options
np.random.seed(0)

sample_sizes = 5000
N = 10

# initialize the result as an array and the standard deviations as an array of size sample sizes
mput_est_M = [None]*sample_sizes
mput_std_M = [None]*sample_sizes

# Generating Monte Carlo estimates as a function of sample size
# The for loop implements Monte Carlo for a number of different sample sizes.
for i in range(1, sample_sizes+1):
    
    # we need N new random variables for each N increasing by a factor of i
    norm_array = norm.rvs(size = N*i)
    
    # used to simulate terminal stock prices
    term_val_M = terminal_shareprice(S_0, risk_free_M, sigma, norm_array, T-current_time)
    
    # These terminal stock prices are passed into the function which values 
    # a put on the stock
    mput_val_M = discounted_put_payoff(term_val, strike, risk_free_M, T-current_time)
    
    # store the mean and SD of these put values
    mput_est_M[i-1] = np.mean(mput_val_M)
    mput_std_M[i-1] = np.std(mput_val_M)/np.sqrt(i*N)

# %%
# Double time
# Share specific info
risk_free = 0.1
S_0 = 100
sigma = 0.3

# Option specific info
strike = 110
T_T = 4
current_time = 0

# Generate Monte Carlo estimates of Vanilla European Put Options
np.random.seed(0)

sample_sizes = 5000
N = 10

# initialize the result as an array and the standard deviations as an array of size sample sizes
mput_est_T = [None]*sample_sizes
mput_std_T = [None]*sample_sizes

# Generating Monte Carlo estimates as a function of sample size
# The for loop implements Monte Carlo for a number of different sample sizes.
for i in range(1, sample_sizes+1):
    
    # we need N new random variables for each N increasing by a factor of i
    norm_array = norm.rvs(size = N*i)
    
    # used to simulate terminal stock prices
    term_val_T = terminal_shareprice(S_0, risk_free, sigma, norm_array, T_T-current_time)
    
    # These terminal stock prices are passed into the function which values 
    # a put on the stock
    mput_val_T = discounted_put_payoff(term_val, strike, risk_free, T_T-current_time)
    
    # store the mean and SD of these put values
    mput_est_T[i-1] = np.mean(mput_val_T)
    mput_std_T[i-1] = np.std(mput_val_T)/np.sqrt(i*N)

# %%
# Double start price
# Share specific info
risk_free = 0.1
S_0_S = 300
sigma = 0.3

# Option specific info
strike = 110
T = 1
current_time = 0

# Generate Monte Carlo estimates of Vanilla European Put Options
np.random.seed(0)

sample_sizes = 5000
N = 10

# initialize the result as an array and the standard deviations as an array of size sample sizes
mput_est_S = [None]*sample_sizes
mput_std_S = [None]*sample_sizes

# Generating Monte Carlo estimates as a function of sample size
# The for loop implements Monte Carlo for a number of different sample sizes.
for i in range(1, sample_sizes+1):
    
    # we need N new random variables for each N increasing by a factor of i
    norm_array = norm.rvs(size = N*i)
    
    # used to simulate terminal stock prices
    term_val_S = terminal_shareprice(S_0_S, risk_free, sigma, norm_array, T-current_time)
    
    # These terminal stock prices are passed into the function which values 
    # a put on the stock
    mput_val_S = discounted_put_payoff(term_val, strike, risk_free, T-current_time)
    
    # store the mean and SD of these put values
    mput_est_S[i-1] = np.mean(mput_val_S)
    mput_std_S[i-1] = np.std(mput_val_S)/np.sqrt(i*N)

# %%
# Double volatility
# Share specific info
risk_free = 0.1
S_0 = 100
sigma_V = 0.6

# Option specific info
strike = 110
T = 1
current_time = 0

# Generate Monte Carlo estimates of Vanilla European Put Options
np.random.seed(0)

sample_sizes = 5000
N = 10

# initialize the result as an array and the standard deviations as an array of size sample sizes
mput_est_V = [None]*sample_sizes
mput_std_V = [None]*sample_sizes

# Generating Monte Carlo estimates as a function of sample size
# The for loop implements Monte Carlo for a number of different sample sizes.
for i in range(1, sample_sizes+1):
    
    # we need N new random variables for each N increasing by a factor of i
    norm_array = norm.rvs(size = N*i)
    
    # used to simulate terminal stock prices
    term_val_V = terminal_shareprice(S_0, risk_free, sigma_V, norm_array, T-current_time)
    
    # These terminal stock prices are passed into the function which values 
    # a put on the stock
    mput_val_V = discounted_put_payoff(term_val_V, strike, risk_free, T-current_time)
    
    # store the mean and SD of these put values
    mput_est_V[i-1] = np.mean(mput_val_V)
    mput_std_V[i-1] = np.std(mput_val_V)/np.sqrt(i*N)

# %%
#double strike price
# Standard options
# Share specific info
risk_free = 0.1
S_0 = 100
sigma = 0.3

# Option specific info
strike_X = 115
T = 1
current_time = 0

# Generate Monte Carlo estimates of Vanilla European Put Options
np.random.seed(0)

sample_sizes = 5000
N = 10

# initialize the result as an array and the standard deviations as an array of size sample sizes
mput_est_X = [None]*sample_sizes
mput_std_X = [None]*sample_sizes

# Generating Monte Carlo estimates as a function of sample size
# The for loop implements Monte Carlo for a number of different sample sizes.
for i in range(1, sample_sizes+1):
    
    # we need N new random variables for each N increasing by a factor of i
    norm_array = norm.rvs(size = N*i)
    
    # used to simulate terminal stock prices
    term_val_X = terminal_shareprice(S_0, risk_free, sigma, norm_array, T-current_time)
    
    # These terminal stock prices are passed into the function which values 
    # a put on the stock
    mput_val_X = discounted_put_payoff(term_val_X, strike_X, risk_free, T-current_time)
    
    # store the mean and SD of these put values
    mput_est_X[i-1] = np.mean(mput_val_X)
    mput_std_X[i-1] = np.std(mput_val_X)/np.sqrt(i*N)

# %%
print(0)
# Out:
# 0

# %%
shift = (np.mean(mput_est_X) - np.mean(mput_est))
plt.figure(figsize=(15,8))
plt.title("Distribution of Terminal Stock Prices Calculated using the Monte Carlo Simulation", fontsize=18)
plt.xlabel("Terminal Stock Prices Calculated", fontsize=18)
plt.ylabel("Times Calculated", fontsize=18)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
#plt.hist(term_val_V, bins=np.arange(0,750,10), ec="black", label='Volatility = 0.6', alpha=0.5,color='green')
plt.hist(term_val, bins=np.arange(0,750,10), ec="black", label='Control conditions', alpha=0.5, color='orange')
#plt.hist(term_val_T, bins=np.arange(0,750,10), ec="black", label='Time = 4yrs', alpha=0.5, color='blue')
#plt.hist(term_val_S, bins=np.arange(0,750,10), ec="black", label='Base price = 300', alpha=0.5, color='yellow')
#plt.hist(term_val_M, bins=np.arange(0,750,10), ec="black", label='Risk-free = 0.3', alpha=0.5, color='red')
#plt.hist(term_val_X, bins=np.arange(0,750,10), ec="black", label='Control conditions', alpha=0.5,color='blue')
#plt.hist(mput_est_X, bins=60, ec="black", label='Double strike price', color="orange", alpha=0.5)
#plt.hist(mput_est_X-shift, bins=60, ec="black", label='Double strike price', alpha=0.5, color="orange")
#plt.scatter(range(0, len(mput_est)), mput_est, 1)
plt.legend(fontsize=16)
#plt.savefig("personal\Dltt_int\Doublestrike")
plt.savefig("DoubleStrike_1.png")
plt.show()
print(np.mean(mput_est))
# Out:
# 11.65805587695541

# %%
# Double volatility
# Share specific info
risk_free = 0.1
S_0 = 100
sigma_V = 0.6

# Option specific info
strike = 110
T = 1
current_time = 0

# Generate Monte Carlo estimates of Vanilla European Put Options
np.random.seed(0)

sample_sizes = 5000
N = 100

# initialize the result as an array and the standard deviations as an array of size sample sizes
mput_est_V = [None]*sample_sizes
mput_std_V = [None]*sample_sizes

# Generating Monte Carlo estimates as a function of sample size
# The for loop implements Monte Carlo for a number of different sample sizes.
for i in range(1, sample_sizes+1):
    
    # we need N new random variables for each N increasing by a factor of i
    norm_array = norm.rvs(size = N*i)
    
    # used to simulate terminal stock prices
    term_val_V = terminal_shareprice(S_0, risk_free, sigma_V, norm_array, T-current_time)
    
    # These terminal stock prices are passed into the function which values 
    # a put on the stock
    mput_val_V = discounted_put_payoff(term_val_V, strike, risk_free, T-current_time)
    
    # store the mean and SD of these put values
    mput_est_V[i-1] = np.mean(mput_val_V)
    mput_std_V[i-1] = np.std(mput_val_V)/np.sqrt(i*N)

# %%
#shift = (np.mean(mput_est_X) - np.mean(mput_est))
plt.figure(figsize=(15,8))
plt.title("Distribution of Terminal Stock Prices Calculated using the Monte Carlo Simulation")
plt.xlabel("Terminal Stock Prices Calculated")
plt.ylabel("Times Calculated")
plt.hist(mput_est, bins=120, ec="black", label='Control conditions', alpha=0.5)
#plt.hist(mput_est_V, bins=60, ec="black", label='Double volatility price', color="orange", alpha=0.5)
#plt.hist(mput_est_X-shift, bins=60, ec="black", label='Double strike price', alpha=0.5, color="orange")
#plt.scatter(range(0, len(mput_est)), mput_est, 1)
plt.legend()
#plt.savefig("personal\Dltt_int\Doublestrike")
plt.savefig("DoubleVolatility.png")
plt.show()

# %%
#shift = (np.mean(mput_est_X) - np.mean(mput_est))
plt.figure(figsize=(15,8))
plt.title("Distribution of Terminal Stock Prices Calculated using the Monte Carlo Simulation")
plt.xlabel("Terminal Stock Prices Calculated")
plt.ylabel("Times Calculated")
plt.hist(mput_est, bins=60, ec="black", label='Control conditions', alpha=0.5)
plt.hist(mput_est_V, bins=60, ec="black", label='Double volatility price', color="orange", alpha=0.5)
#plt.hist(_X-shift, bins=60, ec="black", label='Double strike price', alpha=0.5, color="orange")
#plt.scatter(range(0, len(mput_est)), mput_est, 1)
plt.legend()
#plt.savefig("personal\Dltt_int\Doublestrike")
#plt.savefig("DoubleVolatility.png")
plt.show()

# %%
print(len(term_val))
print(len(term_val_V))
print(len(term_val_X))
print(len(term_val_M))
print(len(term_val_S))
print(len(mput_est_V))
# Out:
# 50000
# 500000
# 50000
# 50000
# 50000
# 5000

# %%
print(np.mean(mput_est))
print(np.mean(mput_std_V))
print(np.mean(mput_std_X))
# Out:
# 11.65805587695541
# 0.06916881643439542
# 0.14251621003736578

# %%
print(f'The base distribution mean is {np.mean(mput_est)}')
print(f'The base distribution std is {np.mean(mput_std)}')
print(f'The volatility distribution mean is {np.mean(mput_est_V)}')
print(f'The volatility distribution std is {np.mean(mput_std_V)}')
print(f'The risk-free distribution mean is {np.mean(mput_est_M)}')
print(f'The risk-free distribution std is {np.mean(mput_std_M)}')
print(f'The base price distribution mean is {np.mean(mput_est_S)}')
print(f'The base price distribution std is {np.mean(mput_std_S)}')
print(f'The strike distribution mean is {np.mean(mput_est_X)}')
print(f'The strike distribution std is {np.mean(mput_std_X)}')
# Out:
# The base distribution mean is 11.65805587695541
# The base distribution std is 0.12846845019076705
# The volatility distribution mean is 23.291993976408463
# The volatility distribution std is 0.06916881643439542
# The risk-free distribution mean is 8.482448806883985
# The risk-free distribution std is 0.0949662269391767
# The base price distribution mean is 11.450108231784908
# The base price distribution std is 0.1281909978561091
# The strike distribution mean is 14.29404064404867
# The strike distribution std is 0.14251621003736578

# %%
d_1 = (np.log(S_0/strike) + (risk_free + sigma**2/2)*(T - current_time))/(sigma*m.sqrt(T-current_time))
d_2 = d_1 - sigma*m.sqrt(T-current_time)

analytic_putprice = -S_0*norm.cdf(-d_1) + strike*m.exp(-risk_free*(T-current_time))*norm.cdf(-d_2)

# plotting the graph
plt.figure(figsize=(15,8))
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
#plt.plot([analytic_putprice]*sample_sizes)
plt.plot(mput_est, label = 'Simulation estimate', color='orange', lw=1.5)
plt.axhline(analytic_putprice, label = 'Black-Scholes price')
#plt.plot(analytic_putprice+3*np.array(mput_std), "r")
#plt.plot(analytic_putprice-3*np.array(mput_std), "r")
plt.xlabel("Sample Size", fontsize=18)
plt.ylabel("Simulation prediction", fontsize=18)
plt.legend(fontsize=18)
plt.savefig("iteration.png")
plt.show()

print(analytic_putprice)
# Out:
# 11.663144941991447
